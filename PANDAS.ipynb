# %%
import pandas as pd

# %%
#TWO MAIN DATATYPES
cars = pd.Series(["Toyota", "BMW", "Honda"])

# %%
cars
# Out:
# 0    Toyota
# 1       BMW
# 2     Honda
# dtype: object

# %%
colors = pd.Series(["Blue", "Orange", "Black", "Yellow"])

# %%
colors
# Out:
# 0      Blue
# 1    Orange
# 2     Black
# 3    Yellow
# dtype: object

# %%
cars_data = pd.DataFrame({"Car Make": cars, "Color": colors})

# %%
cars_data
# Out:
#   Car Make   Color
# 0   Toyota    Blue
# 1      BMW  Orange
# 2    Honda   Black
# 3      NaN  Yellow

# %%
#IMPORT DATA
twitter_data = pd.read_csv("test.csv")

# %%
twitter_data
# Out:
#      4      3  Mon May 11 03:17:40 UTC 2009  kindle2           tpryan  \
# 0    4      4  Mon May 11 03:18:03 UTC 2009  kindle2           vcu451
# 1    4      5  Mon May 11 03:18:54 UTC 2009  kindle2           chadfu
# 2    4      6  Mon May 11 03:19:04 UTC 2009  kindle2            SIX15
# 3    4      7  Mon May 11 03:21:41 UTC 2009  kindle2         yamarama
# 4    4      8  Mon May 11 03:22:00 UTC 2009  kindle2     GeorgeVHulme
# ..  ..    ...                           ...      ...              ...
# 492  2  14072  Sun Jun 14 04:31:43 UTC 2009    latex          proggit
# 493  0  14073  Sun Jun 14 04:32:17 UTC 2009    latex           sam33r
# 494  4  14074  Sun Jun 14 04:36:34 UTC 2009    latex  iamtheonlyjosie
# 495  0  14075  Sun Jun 14 21:36:07 UTC 2009     iran        plutopup7
# 496  0  14076  Sun Jun 14 21:36:17 UTC 2009     iran     captain_pete
#
#     @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# ...

# %%
twitter_data.to_csv("Exported_twitter.csv", index=False)

# %%
re_twitter_data = pd.read_csv("Exported_twitter.csv")
re_twitter_data
# Out:
#      4      3  Mon May 11 03:17:40 UTC 2009  kindle2           tpryan  \
# 0    4      4  Mon May 11 03:18:03 UTC 2009  kindle2           vcu451
# 1    4      5  Mon May 11 03:18:54 UTC 2009  kindle2           chadfu
# 2    4      6  Mon May 11 03:19:04 UTC 2009  kindle2            SIX15
# 3    4      7  Mon May 11 03:21:41 UTC 2009  kindle2         yamarama
# 4    4      8  Mon May 11 03:22:00 UTC 2009  kindle2     GeorgeVHulme
# ..  ..    ...                           ...      ...              ...
# 492  2  14072  Sun Jun 14 04:31:43 UTC 2009    latex          proggit
# 493  0  14073  Sun Jun 14 04:32:17 UTC 2009    latex           sam33r
# 494  4  14074  Sun Jun 14 04:36:34 UTC 2009    latex  iamtheonlyjosie
# 495  0  14075  Sun Jun 14 21:36:07 UTC 2009     iran        plutopup7
# 496  0  14076  Sun Jun 14 21:36:17 UTC 2009     iran     captain_pete
#
#     @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# ...

# %% [markdown]
# # DESCRIBING DATA

# %%
cars_data.dtypes
# Out:
# Car Make    object
# Color       object
# dtype: object

# %%
twitter_data.dtypes
# Out:
# 4                                                                                                                   int64
# 3                                                                                                                   int64
# Mon May 11 03:17:40 UTC 2009                                                                                       object
# kindle2                                                                                                            object
# tpryan                                                                                                             object
# @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.    object
# dtype: object

# %%
cars_data.columns
# Out:
# Index(['Car Make', 'Color'], dtype='object')

# %%
twitter_data.columns
# Out:
# Index(['4', '3', 'Mon May 11 03:17:40 UTC 2009', 'kindle2', 'tpryan',
#        '@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.'],
#       dtype='object')

# %%
twitter_data_columns = twitter_data.columns

# %%
twitter_data_columns
# Out:
# Index(['4', '3', 'Mon May 11 03:17:40 UTC 2009', 'kindle2', 'tpryan',
#        '@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.'],
#       dtype='object')

# %%
cars_data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
cars_data.describe()
# Out:
#        Car Make Color
# count         3     4
# unique        3     4
# top      Toyota  Blue
# freq          1     1

# %%
twitter_data.describe()
# Out:
#                 4             3
# count  497.000000    497.000000
# mean     2.016097   1870.977867
# std      1.699069   2836.510683
# min      0.000000      4.000000
# 25%      0.000000    389.000000
# 50%      2.000000   1014.000000
# 75%      4.000000   2367.000000
# max      4.000000  14076.000000

# %%
cars_data
# Out:
#   Car Make   Color
# 0   Toyota    Blue
# 1      BMW  Orange
# 2    Honda   Black
# 3      NaN  Yellow

# %%
car_prices = pd.Series([3000, 12241, 131255, 124124])
car_prices.mean()
# Out:
# 67655.0

# %%
car_prices.sum()
# Out:
# 270620

# %%
cars_data.sum()
# Out:
# C:\Users\Urahara Kiseke\AppData\Local\Temp\ipykernel_8440\4130290644.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cars_data.sum()
# Color    BlueOrangeBlackYellow
# dtype: object

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Car Make  3 non-null      object
#  1   Color     4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
twitter_data.sum()
# Out:
# 4                                                                                                                                                               1002
# 3                                                                                                                                                             929876
# Mon May 11 03:17:40 UTC 2009                                                                                       Mon May 11 03:18:03 UTC 2009Mon May 11 03:18:5...
# kindle2                                                                                                            kindle2kindle2kindle2kindle2kindle2aigjquerytw...
# tpryan                                                                                                             vcu451chadfuSIX15yamaramaGeorgeVHulmeSeth937dc...
# ...

# %%
twitter_data.columns
# Out:
# Index(['4', '3', 'Mon May 11 03:17:40 UTC 2009', 'kindle2', 'tpryan',
#        '@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.'],
#       dtype='object')

# %%
twitter_data["4"].sum()
# Out:
# 1002

# %%
len(twitter_data["4"])
# Out:
# 497

# %% [markdown]
# # SELECTING AND VIEWING DATA USING PANDAS

# %%
cars_data.head()
# Out:
#   Car Make   Color
# 0   Toyota    Blue
# 1      BMW  Orange
# 2    Honda   Black
# 3      NaN  Yellow

# %%
twitter_data.head()
# Out:
#    4  3  Mon May 11 03:17:40 UTC 2009  kindle2        tpryan  \
# 0  4  4  Mon May 11 03:18:03 UTC 2009  kindle2        vcu451
# 1  4  5  Mon May 11 03:18:54 UTC 2009  kindle2        chadfu
# 2  4  6  Mon May 11 03:19:04 UTC 2009  kindle2         SIX15
# 3  4  7  Mon May 11 03:21:41 UTC 2009  kindle2      yamarama
# 4  4  8  Mon May 11 03:22:00 UTC 2009  kindle2  GeorgeVHulme
#
#   @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 0  Reading my kindle2...  Love it... Lee childs i...
# 1  Ok, first assesment of the #kindle2 ...it fuck...
# 2  @kenburbary You'll love your Kindle2. I've had...
# 3  @mikefish  Fair enough. But i have the Kindle2...
# 4  @richardebaker no. it is too big. I'm quite ha...

# %%
twitter_data.head(8)
# Out:
#    4   3  Mon May 11 03:17:40 UTC 2009  kindle2        tpryan  \
# 0  4   4  Mon May 11 03:18:03 UTC 2009  kindle2        vcu451
# 1  4   5  Mon May 11 03:18:54 UTC 2009  kindle2        chadfu
# 2  4   6  Mon May 11 03:19:04 UTC 2009  kindle2         SIX15
# 3  4   7  Mon May 11 03:21:41 UTC 2009  kindle2      yamarama
# 4  4   8  Mon May 11 03:22:00 UTC 2009  kindle2  GeorgeVHulme
# 5  0   9  Mon May 11 03:22:30 UTC 2009      aig       Seth937
# 6  4  10  Mon May 11 03:26:10 UTC 2009   jquery     dcostalis
# 7  4  11  Mon May 11 03:27:15 UTC 2009  twitter       PJ_King
#
#   @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 0  Reading my kindle2...  Love it... Lee childs i...
# 1  Ok, first assesment of the #kindle2 ...it fuck...
# 2  @kenburbary You'll love your Kindle2. I've had...
# 3  @mikefish  Fair enough. But i have the Kindle2...
# 4  @richardebaker no. it is too big. I'm quite ha...
# ...

# %%
twitter_data.tail()
# Out:
#      4      3  Mon May 11 03:17:40 UTC 2009 kindle2           tpryan  \
# 492  2  14072  Sun Jun 14 04:31:43 UTC 2009   latex          proggit
# 493  0  14073  Sun Jun 14 04:32:17 UTC 2009   latex           sam33r
# 494  4  14074  Sun Jun 14 04:36:34 UTC 2009   latex  iamtheonlyjosie
# 495  0  14075  Sun Jun 14 21:36:07 UTC 2009    iran        plutopup7
# 496  0  14076  Sun Jun 14 21:36:17 UTC 2009    iran     captain_pete
#
#     @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 492  Ask Programming: LaTeX or InDesign?: submitted...
# 493  On that note, I hate Word. I hate Pages. I hat...
# 494  Ahhh... back in a *real* text editing environm...
# 495  Trouble in Iran, I see. Hmm. Iran. Iran so far...
# 496  Reading the tweets coming out of Iran... The w...

# %%
animals = pd.Series(["Frog", "Dog", "Cat"], index=[5,2,2])
animals
# Out:
# 5    Frog
# 2     Dog
# 2     Cat
# dtype: object

# %%
#LOC REFERS TO INDEX OR MULTIPLE INDEXES
animals.loc[2]
# Out:
# 2    Dog
# 2    Cat
# dtype: object

# %%
cars_data.loc[3]
# Out:
# Car Make       NaN
# Color       Yellow
# Name: 3, dtype: object

# %%
#ILOC REFERS TO THE LOCATION
animals.iloc[2]
# Out:
# 'Cat'

# %%
animals.loc[:2]
# Out:
# 5    Frog
# 2     Dog
# 2     Cat
# dtype: object

# %%
cars_data.loc[:2]
# Out:
#   Car Make   Color
# 0   Toyota    Blue
# 1      BMW  Orange
# 2    Honda   Black

# %%
twitter_data
# Out:
#      4      3  Mon May 11 03:17:40 UTC 2009  kindle2           tpryan  \
# 0    4      4  Mon May 11 03:18:03 UTC 2009  kindle2           vcu451
# 1    4      5  Mon May 11 03:18:54 UTC 2009  kindle2           chadfu
# 2    4      6  Mon May 11 03:19:04 UTC 2009  kindle2            SIX15
# 3    4      7  Mon May 11 03:21:41 UTC 2009  kindle2         yamarama
# 4    4      8  Mon May 11 03:22:00 UTC 2009  kindle2     GeorgeVHulme
# ..  ..    ...                           ...      ...              ...
# 492  2  14072  Sun Jun 14 04:31:43 UTC 2009    latex          proggit
# 493  0  14073  Sun Jun 14 04:32:17 UTC 2009    latex           sam33r
# 494  4  14074  Sun Jun 14 04:36:34 UTC 2009    latex  iamtheonlyjosie
# 495  0  14075  Sun Jun 14 21:36:07 UTC 2009     iran        plutopup7
# 496  0  14076  Sun Jun 14 21:36:17 UTC 2009     iran     captain_pete
#
#     @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# ...

# %%
cars_data
# Out:
#   Car Make   Color
# 0   Toyota    Blue
# 1      BMW  Orange
# 2    Honda   Black
# 3      NaN  Yellow

# %%
cars_data.Color
# Out:
# 0      Blue
# 1    Orange
# 2     Black
# 3    Yellow
# Name: Color, dtype: object

# %%
car_data = pd.read_csv("cars_data.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data[car_data["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_data[car_data["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#CROSS TAB
car_data_crosstab = pd.crosstab(car_data["Make"], car_data["Doors"])
car_data_crosstab
#ABOVE EXPLANATION WHICH GOES AS:
#BMW has one car with 5 doors, Honda has 3 cars with 4 doors and Nissan has 2 cars with 4 doors.
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
type(car_data_crosstab)
# Out:
# pandas.core.frame.DataFrame

# %%
#getting a single column
car_data_crosstab.get(5)
# Out:
# Make
# BMW       1
# Honda     0
# Nissan    0
# Toyota    0
# Name: 5, dtype: int64

# %%
car_data_crosstab.get(5)[0]
# Out:
# 1

# %%
#GroupBy
car_data.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#PLOT
car_data["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
#HISTOGRAM
car_data["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_data["Price"].dtype
#'O' MEANS OBEJCT
# Out:
# dtype('int32')

# %%
#car_data["Price"] = car_data["Price"].replace('[\$\,\.]', '').astype(int)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_data["Make"].dtype
# Out:
# dtype('O')

# %%
car_data["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_data["Make"] = car_data["Make"].str.lower()

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_data_missing = pd.read_csv("car_data_missing.csv")

# %%
car_data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_data_missing["Odometer"].fillna(car_data_missing["Odometer"].mean(), inplace=True)
#We can also fo the same thing using the assignment method.

# %%
car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_data_missing.dropna(inplace=True)

# %%
car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_data_missing.to_csv("car_data_missing_dropped.csv")

# %%
seats = pd.Series([5,5,5,5,5])
#Adding new column called seats
car_data["Seats"] = seats

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_data["Seats"].fillna(5, inplace=True)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
#Adding the new column
fuel_economy = [4.7, 5.5, 1.6, 7.6, 8.9, 5.4, 3.5, 3.7, 2.2, 8.8]
car_data["Fuel per 100Km"] = fuel_economy

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km
# 0  toyota  White         150043      4   400000    5.0             4.7
# 1   honda    Red          87899      4   500000    5.0             5.5
# 2  toyota   Blue          32549      3   700000    5.0             1.6
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             8.9
# 5  toyota  Green          99213      4   450000    5.0             5.4
# 6   honda   Blue          45698      4   750000    5.0             3.5
# 7   honda   Blue          54738      4   700000    5.0             3.7
# 8  toyota  White          60000      4   625000    5.0             2.2
# 9  nissan  White          31600      4   970000    5.0             8.8

# %%
car_data["Total Fuel Used (L)"] = car_data["Odometer (KM)"]/100 * car_data["Fuel per 100Km"]

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 0  toyota  White         150043      4   400000    5.0             4.7
# 1   honda    Red          87899      4   500000    5.0             5.5
# 2  toyota   Blue          32549      3   700000    5.0             1.6
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             8.9
# 5  toyota  Green          99213      4   450000    5.0             5.4
# 6   honda   Blue          45698      4   750000    5.0             3.5
# 7   honda   Blue          54738      4   700000    5.0             3.7
# 8  toyota  White          60000      4   625000    5.0             2.2
# 9  nissan  White          31600      4   970000    5.0             8.8
#
#    Total Fuel Used
# 0         7052.021
# 1         4834.445
# 2          520.784
# 3          849.604
# 4        18965.455
# 5         5357.502
# 6         1599.430
# 7         2025.306
# ...

# %%
#Adding a column ased on a single value
car_data["Passed road tests"] = True

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 0  toyota  White         150043      4   400000    5.0             4.7
# 1   honda    Red          87899      4   500000    5.0             5.5
# 2  toyota   Blue          32549      3   700000    5.0             1.6
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             8.9
# 5  toyota  Green          99213      4   450000    5.0             5.4
# 6   honda   Blue          45698      4   750000    5.0             3.5
# 7   honda   Blue          54738      4   700000    5.0             3.7
# 8  toyota  White          60000      4   625000    5.0             2.2
# 9  nissan  White          31600      4   970000    5.0             8.8
#
#    Total Fuel Used  Passed road tests  Total Fuel Used (L)
# 0         7052.021               True             7052.021
# 1         4834.445               True             4834.445
# ...

# %%
#Dropping a column
car_data = car_data.drop("Total Fuel Used", axis=1)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 0  toyota  White         150043      4   400000    5.0             4.7
# 1   honda    Red          87899      4   500000    5.0             5.5
# 2  toyota   Blue          32549      3   700000    5.0             1.6
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             8.9
# 5  toyota  Green          99213      4   450000    5.0             5.4
# 6   honda   Blue          45698      4   750000    5.0             3.5
# 7   honda   Blue          54738      4   700000    5.0             3.7
# 8  toyota  White          60000      4   625000    5.0             2.2
# 9  nissan  White          31600      4   970000    5.0             8.8
#
#    Passed road tests  Total Fuel Used (L)
# 0               True             7052.021
# 1               True             4834.445
# 2               True              520.784
# ...

# %%
#Sample used to shuffle the data around
car_data_shuffled = car_data.sample(frac=1)
car_data_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 4  nissan  White         213095      4   350000    5.0             8.9
# 7   honda   Blue          54738      4   700000    5.0             3.7
# 6   honda   Blue          45698      4   750000    5.0             3.5
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 5  toyota  Green          99213      4   450000    5.0             5.4
# 0  toyota  White         150043      4   400000    5.0             4.7
# 1   honda    Red          87899      4   500000    5.0             5.5
# 2  toyota   Blue          32549      3   700000    5.0             1.6
# 9  nissan  White          31600      4   970000    5.0             8.8
# 8  toyota  White          60000      4   625000    5.0             2.2
#
#    Passed road tests  Total Fuel Used (L)
# 4               True            18965.455
# 7               True             2025.306
# 6               True             1599.430
# ...

# %%
#Selecting 20% of the data
car_data.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 8  toyota  White          60000      4   625000    5.0             2.2
#
#    Passed road tests  Total Fuel Used (L)
# 3               True              849.604
# 8               True             1320.000

# %%
car_data_shuffled.reset_index(drop=True, inplace=True)

# %%
car_data_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 0  nissan  White         213095      4   350000    5.0             8.9
# 1   honda   Blue          54738      4   700000    5.0             3.7
# 2   honda   Blue          45698      4   750000    5.0             3.5
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  toyota  Green          99213      4   450000    5.0             5.4
# 5  toyota  White         150043      4   400000    5.0             4.7
# 6   honda    Red          87899      4   500000    5.0             5.5
# 7  toyota   Blue          32549      3   700000    5.0             1.6
# 8  nissan  White          31600      4   970000    5.0             8.8
# 9  toyota  White          60000      4   625000    5.0             2.2
#
#    Passed road tests  Total Fuel Used (L)
# 0               True            18965.455
# 1               True             2025.306
# 2               True             1599.430
# ...

# %%
car_data["Odometer (KM)"] = car_data["Odometer (KM)"].apply(lambda x: x / 1.6)
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100Km  \
# 0  toyota  White      93776.875      4   400000    5.0             4.7
# 1   honda    Red      54936.875      4   500000    5.0             5.5
# 2  toyota   Blue      20343.125      3   700000    5.0             1.6
# 3     bmw  Black       6986.875      5  2200000    5.0             7.6
# 4  nissan  White     133184.375      4   350000    5.0             8.9
# 5  toyota  Green      62008.125      4   450000    5.0             5.4
# 6   honda   Blue      28561.250      4   750000    5.0             3.5
# 7   honda   Blue      34211.250      4   700000    5.0             3.7
# 8  toyota  White      37500.000      4   625000    5.0             2.2
# 9  nissan  White      19750.000      4   970000    5.0             8.8
#
#    Passed road tests  Total Fuel Used (L)
# 0               True             7052.021
# 1               True             4834.445
# 2               True              520.784
# ...
